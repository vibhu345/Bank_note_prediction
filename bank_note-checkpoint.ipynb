# %%
import pandas as pd
df=pd.read_csv("train.csv")
df.head()
# Class 0 means fake note and one means real note 
# data exploration 
df.isnull().sum() # no null values
df=df.drop_duplicates() # droped all the duplicate values
df.info()
# checking whether the dataset is balanced or not
df.Class.value_counts() # plz balance the dataset
from sklearn.model_selection import train_test_split
x=df.drop("Class",axis=1)
y=df["Class"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
x_train,x_val,y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)
print("Null",x_train.isnull().sum())
print("Null",x_test.isnull().sum())
print("Null",y_train.isnull().sum())
print("Null",y_test.isnull().sum())
# scalling and encoding
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train=pd.DataFrame(x_train,columns=scaler.get_feature_names_out())
x_val=scaler.fit_transform(x_val)
x_val=pd.DataFrame(x_val,columns=scaler.get_feature_names_out())
x_test=scaler.transform(x_test)
x_test=pd.DataFrame(x_test,columns=scaler.get_feature_names_out())
# model building
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout,Dense
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1079 entries, 0 to 1095
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VWTI    1079 non-null   float64
#  1   SWTI    1079 non-null   float64
#  2   CWTI    1079 non-null   float64
#  3   EI      1079 non-null   float64
#  4   Class   1079 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 50.6 KB
# Null VWTI    0
# SWTI    0
# CWTI    0
# EI      0
# dtype: int64
# Null VWTI    0
# SWTI    0
# CWTI    0
# EI      0
# dtype: int64
# Null 0
# Null 0

# %%
model=Sequential([
    # input layer
    Dense(units=128,input_shape=(x_train.shape[1],)),
    Dropout(0.3),
    Dense(units=64,activation="relu"),
    Dropout(0.3),
    Dense(units=32,activation="relu"),
    Dropout(0.3),
    Dense(units=16,activation="relu"),
    Dropout(0.3),
    Dense(units=8,activation="relu"),
    Dropout(0.3),
    Dense(1,activation="sigmoid")
    
])
model.compile(optimizer="Adam",loss="binary_crossentropy",metrics=["accuracy"])
# adding early stopping to prevent overfitting
es=EarlyStopping(monitor="val_loss",patience=5,restore_best_weights=True)
model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 128)                 │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │           8,256 │
# ...

# %%
# training the model
history=model.fit(x_train,y_train,batch_size=32,epochs=20,validation_data=(x_val,y_val),callbacks=[es])
# Out:
# Epoch 1/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.6536 - loss: 0.6209 - val_accuracy: 0.8439 - val_loss: 0.4712
# Epoch 2/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8072 - loss: 0.4625 - val_accuracy: 0.9017 - val_loss: 0.2695
# Epoch 3/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8971 - loss: 0.2983 - val_accuracy: 0.9769 - val_loss: 0.1109
# Epoch 4/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9435 - loss: 0.1958 - val_accuracy: 0.9884 - val_loss: 0.0485
# Epoch 5/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9681 - loss: 0.1190 - val_accuracy: 0.9884 - val_loss: 0.0395
# Epoch 6/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9623 - loss: 0.1075 - val_accuracy: 0.9884 - val_loss: 0.0311
# Epoch 7/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9797 - loss: 0.0753 - val_accuracy: 0.9884 - val_loss: 0.0259
# Epoch 8/20
# ...

# %%
history.history
# Out:
# {'accuracy': [0.6536231637001038,
#   0.8072463870048523,
#   0.8971014618873596,
#   0.9434782862663269,
#   0.9681159257888794,
#   0.9623188376426697,
#   0.9797101616859436,
#   0.9768115878105164,
#   0.9768115878105164,
#   0.9826086759567261,
#   0.9811594486236572,
#   0.9971014261245728,
#   0.9797101616859436,
#   0.991304337978363,
#   0.9956521987915039,
#   0.9898550510406494],
#  'loss': [0.6208716034889221,
#   0.4625120759010315,
#   0.2982649505138397,
#   0.195782870054245,
#   0.11901485174894333,
#   0.10750328749418259,
#   0.07529806345701218,
#   0.07403168082237244,
#   0.0742252990603447,
#   0.07629285752773285,
#   0.06397203356027603,
#   0.03010062873363495,
#   0.047789331525564194,
#   0.03375381976366043,
#   0.03914058580994606,
#   0.032659899443387985],
#  'val_accuracy': [0.8439306616783142,
#   0.9017341136932373,
#   0.9768785834312439,
#   0.9884393215179443,
#   0.9884393215179443,
#   0.9884393215179443,
#   0.9884393215179443,
# ...

# %%
test_loss,test_accuracy=model.evaluate(x_test,y_test)
print(test_loss,test_accuracy)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9907 - loss: 0.0188
# 0.01884564198553562 0.9907407164573669

# %%
y_pred=(model.predict(x_test)>0.5).astype("int")
from sklearn.metrics import accuracy_score
y_pred
print(accuracy_score(y_test,y_pred))
# the predict function banega and then thoda visualization
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 0.9907407407407407

# %%
t=0.7
(t>0.5).astype("int")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 t=0.7
# ----> 2 (t>0.5).astype("int")
#
# AttributeError: 'bool' object has no attribute 'astype'
